# %% [markdown]
# Venkatesh Godi-BMB2058

# %%
T=(3,6,9,12,5,3,2)
print("T-->",T)
print("T[1]-->",T[1])
print("T[2]-->",T[2])
print("T[3]-->",T[3])
# Out:
# T--> (3, 6, 9, 12, 5, 3, 2)
# T[1]--> 6
# T[2]--> 9
# T[3]--> 12

# %%
print("T[1:3]-->",T[1:3])
print("T[2:5] -->",T[2:5])
print("T[0:5]-->",T[0:5])
print("T[:-1]-->",T[:-1])
# Out:
# T[1:3]--> (6, 9)
# T[2:5] --> (9, 12, 5)
# T[0:5]--> (3, 6, 9, 12, 5)
# T[:-1]--> (3, 6, 9, 12, 5, 3)

# %%
print("T[-4:1]-->",T[-4:1])
# Out:
# T[-4:1]--> ()

# %%
print("T[-3:-5]-->",T[-3:-5])
# Out:
# T[-3:-5]--> ()

# %%
print("T[::1]-->",T[::1])
# Out:
# T[::1]--> (3, 6, 9, 12, 5, 3, 2)

# %%
T=("paru","rama","shama")
T[2]=900
print("T-->",T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3202096985.py in <cell line: 0>()
#       1 T=("paru","rama","shama")
# ----> 2 T[2]=900
#       3 print("T-->",T)
#
# TypeError: 'tuple' object does not support item assignment

# %%
T=("paru","rama","shama")
T.append(9.8).ins
T.insert(2,"rahul")
T.add(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-791679026.py in <cell line: 0>()
#       1 T=("paru","rama","shama")
# ----> 2 T.append(9.8)
#       3 T.insert(2,"rahul")
#       4 T.add(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T.insert(2,"rahul")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-678600356.py in <cell line: 0>()
# ----> 1 T.insert(2,"rahul")
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
T=("pratham","shama,3.14,3")
print("T-->",T)
T1=list(T)
T1.append(9.8)
T=tuple(T1)
print("T-->",T)
# Out:
# T--> ('pratham', 'shama', 3.14, 3)
# T--> ('pratham', 'shama', 3.14, 3, 9.8)

# %%
T1
T=list(T1)
T1.insert(2,"rahul")
T=tuple(T1)
print("")
print("after inser-->",T)
# Out:
# after inser--> ('pratham', 'shama', 'rahul', 3.14, 3, 9.8)

# %%
T=list(T1)
del T1[1]
T=tuple(T1)
print("")
print("after delete-->",T)
# Out:
# after delete--> ('pratham', 'rahul', 3.14, 3, 9.8)

# %%
T=(3,6,9,12,5,3,2)
print("T-->",T)
print("sum-->",sum(T))
print("max-->",max(T))
print("min-->",min(T))
print("average -->",sum(T)/len(T))
print("average-->",sum(T)//len(T))
# Out:
# T--> (3, 6, 9, 12, 5, 3, 2)
# sum--> 40
# max--> 12
# min--> 2
# average --> 5.714285714285714
# average--> 5

# %%
T1=(3,6,9)
T2=(12,5,3,2)
T3=T1+T2
print("T1-->",T1)
T3=T1+T2
print("T3-->",T3)
# Out:
# T1--> (3, 6, 9)
# T3--> (3, 6, 9, 12, 5, 3, 2)

# %%
T3=T1[1:2]+T2[1:3]
print("T3-->",T3)
T4=T1[:-2]+T2[:-3]
print("T4-->",T4)
# Out:
# T3--> (6, 5, 3)
# T4--> (3, 12)

# %%
T=(3,6,9,12,5,3,2)
print("T-->",T)
print("")
print("Index of 9 in T",T.index(9))
print("Index of 3 in T",T.index(3))
print("")
print("Count of 3 in T",T.count(3))
# Out:
# T--> (3, 6, 9, 12, 5, 3, 2)
#
# Index of 9 in T 2
# Index of 3 in T 0
#
# Count of 3 in T 2

# %%
print("T.count(2)-->",T.count(2))
# Out:
# T.count(2)--> 1

# %%
l1=[1,2,3]
print(id(l1))
l1.append(4)
print(id(l1))
# Out:
# 139101805965120
# 139101805965120

# %%
set={1,2,3}
print(id(set))
set.add(4)
print(id(set))
# Out:
# 139101807406080
# 139101807406080

# %%
a="GKVK"
print(id(a))
a=a+"university"
print(id(a))
# Out:
# 139101784486992
# 139101805965872

# %%
s="python"
print(id(s))
s=s+"3"
print(id(s))
print(s)
# Out:
# 139102779734944
# 139101800505168
# python3

# %%
s="python"
s[0]="j"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2144580629.py in <cell line: 0>()
#       1 s="python"
# ----> 2 s[0]="j"
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))
x=x+20
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11655304
# 11654664
