# %% [markdown]
# Venkatesh Godi-BMB2058

# %%
list1=[1,2,3]
print(list1)
# Out:
# [1, 2, 3]

# %%
list1=[1,2,3,4]
print(len(list1))
# Out:
# 4

# %%
list1=[1,2,3,4]
print(list1.index(2))
# Out:
# 1

# %%
list1=[1,2,3,4]
list1.append('5')
print(list1)
# Out:
# [1, 2, 3, 4, '5']

# %%
list1=[1,2,3,3,3]
print(list1.count(3))
# Out:
# 3

# %%
list1=['hi',1,2,3]
list1.insert(1,'hello')
print(list1)
# Out:
# ['hi', 'hello', 1, 2, 3]

# %%
list1=[1,2,3,4]
list1.insert(4,'hiii')
print(list1)
# Out:
# [1, 2, 3, 4, 'hiii']

# %%
list1=[1,2,3,'hiiii']
list1.reverse()
print(list1)
# Out:
# ['hiiii', 3, 2, 1]

# %%
list1=['hiiii',1,2,3,4]
list1.reverse()
print(list1)
# Out:
# [4, 3, 2, 1, 'hiiii']

# %%
list1=['hi','hello']
print(len(list1))
# Out:
# 2

# %%
list1=[1,2,3,4,5,6]
print(list1.index(6))
# Out:
# 5

# %%
list1=['hi','wyd','how are you']
print(list1.pop(1))
print(list1)
# Out:
# wyd
# ['hi', 'how are you']

# %%
list1=[1,2,3,4]
print(list1.pop(2))
print(list1)
# Out:
# 3
# [1, 2, 4]

# %%
list1=[1,2,3,4,'hi']
list1.remove(2)
print(list1)
# Out:
# [1, 3, 4, 'hi']

# %%
list1=['hi','smile','life']
list1.remove('life')
print(list1)
# Out:
# ['hi', 'smile']

# %%
list1=[1,2,3,4,'hi']
list1.clear()
print(list1)
# Out:
# []

# %%
list1=[]
list1.clear()
print(list1)
# Out:
# []

# %%
list1=[1,2,3,4,'hi']
del(list1)
print(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1530584576.py in <cell line: 0>()
#       1 list1=[1,2,3,4,'hi']
#       2 del(list1)
# ----> 3 print(list1)
#
# NameError: name 'list1' is not defined

# %%
list1=[1,23,3]
del(list1)
print(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2537484829.py in <cell line: 0>()
#       1 list1=[1,23,3]
#       2 del(list1)
# ----> 3 print(list1)
#
# NameError: name 'list1' is not defined

# %%
list1=[144,24456,3555,990]
list1.sort()
print(list1)
# Out:
# [144, 990, 3555, 24456]

# %%
list1=[144,24456,3555,990 ]
print(max(list1))
# Out:
# 24456

# %%
list1=[1234,34566,12345678]
print(min(list1))
# Out:
# 1234

# %%
list1=[1,2,3,4,4]
print(sum(list1))
# Out:
# 14

# %%
list1=['a','b','c','d','A']
list1.sort()
print(list1)
# Out:
# ['A', 'a', 'b', 'c', 'd']

# %%
list1=["Harshithaaa","Harsh"]
list1.sort()
print(list1)
# Out:
# ['Harsh', 'Harshithaaa']

# %%
a=[1,23,45,67]
b=a
print("a",a)
print("b",b)
b.insert(1,55)
print("a:",a)
print("b:",b)
# Out:
# a [1, 23, 45, 67]
# b [1, 23, 45, 67]
# a: [1, 55, 23, 45, 67]
# b: [1, 55, 23, 45, 67]

# %%
a=[1,23,45,67]
b=a.copy()
print("a",a)
print("b",b)
b.insert(4,55)
print("a:",a)
print("b:",b)
# Out:
# a [1, 23, 45, 67]
# b [1, 23, 45, 67]
# a: [1, 23, 45, 67]
# b: [1, 23, 45, 67, 55]
