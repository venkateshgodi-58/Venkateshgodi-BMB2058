# %% [markdown]
# Venkatesh Godi-BMB2058

# %%
# program to add number
print(2+3)
# Out:
# 5

# %%
if 10>5:
   print("10 is grater than 5")
# Out:
# 10 is grater than 5

# %%
a=12
b=7
if a>b:
  print("a is grater than b")
# Out:
# a is grater than b

# %%
a=10
b=20
if a>b:
  print("a is grater than b")
else:
  print("b is grater than a")
# Out:
# b is grater than a

# %%
a=20
if(a>=18):
  print("eligible for vote")
else:
  print("not eligible for vote")
# Out:
# eligible for vote

# %%
num=0
if num>0:
  print("num is positive")
elif(num<0):
  print("num is negative")
else:
   print("num is  zero")
# Out:
# num is  zero

# %%
grade=9
if grade>9:
  print("a grade")
elif("grade>7 and grade=<9"):
   print("b grade")
elif("grade>5 and grade<7"):
   print("c grade")
else:
   print("fail")
# Out:
# b grade

# %%
num=9
if num%2==0:
  print("num is even")
else:
  print("num is odd")
# Out:
# num is odd

# %%
# list of soil moisture level in percentage
soil_moisture=[45,60,30,55,40]

# %%
soil_moisture=[45,60,30,55,40]
print("soil_moisture levels in differnt fields:")
for moisture in soil_moisture:
  print(moisture,"%")
# Out:
# soil_moisture levels in differnt fields:
# 45 %
# 60 %
# 30 %
# 55 %
# 40 %

# %%
soil_moisture=[45,60,30,55,40]
print("\n Fields that need irrigation:")
for moisture in soil_moisture:
  if moisture <50:
    print(moisture,"% irrigation needed")
  else:
    print(moisture,"% sufficient moisture")

#total number of fields
print("\n Total number of fields:",len(soil_moisture))
# Out:
#  Fields that need irrigation:
# 45 % irrigation needed
# 60 % sufficient moisture
# 30 % irrigation needed
# 55 % sufficient moisture
# 40 % irrigation needed
#
#  Total number of fields: 5

# %%
soil_moisture=[45,60,30,55,40]
soil_moisture.append(65)
print("after adding new field moisture:")
print(soil_moisture)

print("total field checked:",len(soil_moisture))
# Out:
# after adding new field moisture:
# [45, 60, 30, 55, 40, 65]
# total field checked: 6

# %%
soil_moisture=[45,60,30,55,40]
soil_moisture.remove(30)
print("after removing 30% moisture value:")
print(soil_moisture)

print("total field checked:",len(soil_moisture))
# Out:
# after removing 30% moisture value:
# [45, 60, 55, 40]
# total field checked: 4

# %%
names=['lakshmi','swetha','rama']
age=[21,20,22]
for i in range(len(names)):
  print(names[i],"age is",age[i])
# Out:
# lakshmi age is 21
# swetha age is 20
# rama age is 22

# %%
names=['lakshmi','swetha','rama']
age=[21,20,22]
for n,a in zip(names,age):
  print(n,"age is", a)
# Out:
# lakshmi age is 21
# swetha age is 20
# rama age is 22

# %%
crops=["rice","wheat","millet","maize","pulses"]
water_need=[300,200,100,150,80] #in mm
print("length",len(crops))
print("range",range(len(crops)))
print("crop and water requirement:")
for i in range (len(crops)):
  print(crops[i],"-" ,water_need[i],"mm")
# Out:
# length 5
# range range(0, 5)
# crop and water requirement:
# rice - 300 mm
# wheat - 200 mm
# millet - 100 mm
# maize - 150 mm
# pulses - 80 mm

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]  #tons per hectare
average_yield=sum(yield_tons)/len(yield_tons)
print("high yield crops:")
for i in range(len(crops)):
  if yield_tons[i]>average_yield:
        print(crops[i])
# Out:
# rice water_need 300
# wheat water_need 200
# millet water_need 100
# maize water_need 150
# pulses water_need 80

# %%
crops=["rice","wheat","millet","maize","pulses"]
water_need=[300,200,100,150,80] #in mm
print("crops needing high water(>180mm)")
for i in range (len(water_need)):
  if water_need[i]>180:
    print(crops[i])
# Out:
# crops needing high water(>180mm)
# rice
# wheat

# %%
crops=["rice","wheat","millet","maize","pulses"]
water_need=[300,200,100,150,80] #in mm
print ("crops needing high water(>180mm)")
for c,w in zip(crops,water_need):
  if w>180:
    print(c)
# Out:
# crops needing high water(>180mm)
# rice
# wheat

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]  #tons per hectare
average_yield=sum(yield_tons)/len(yield_tons)
print("average yield is",average_yield,"tons per hectare")
# Out:
# average yield is 2.95 tons per hectare

# %%
crops=["rice","wheat","millet","maize","pulses"]
water_need=[300,200,100,150,80]
max_water=max(water_need)
index=water_need.index(max_water)
print("crop with highest water requirement:",crops[index])
# Out:
# crop with highest water requirement: rice

# %%
max_crop=max(zip(water_need,crops))
print(max_crop)
print("crop with highest water requirement:",max_crop[1])
# Out:
# (300, 'rice')
# crop with highest water requirement: rice

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]  #tons per hectare
max_yield=max(yield_tons)
index=yield_tons.index(max_yield)
print("crop with highest yield:",crops[index])
# Out:
# crop with highest yield: wheat

# %%
max_crop=max(zip(yield_tons,crops))
print(max_crop)
print("crop with highest yield:",max_crop[1])
# Out:
# (4.0, 'wheat')
# crop with highest yield: wheat

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]  #tons per hectare
average_yield=sum(yield_tons)/len(yield_tons)
print("high yield crops:")
for i in range(len(crops)):
  if yield_tons[i]>average_yield:
        print(crops[i])
# Out:
# high yield crops:
# rice
# wheat

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]  #tons per hectare
average_yield=sum(yield_tons)/len(yield_tons)
print("high yield crops:")
for crop, yield_value in zip(crops, yield_tons):
  if yield_value > average_yield:
    print(crop)
# Out:
# high yield crops:
# rice
# wheat

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]  #tons per hectare
average_yield=sum(yield_tons)/len(yield_tons)
print("average yield is",average_yield,"tons per hectare")
for c,y in zip(crop,yield_tons):
  if y>average_yield:
# Out:
#   File "/tmp/ipython-input-1965742054.py", line 6
#     if y>average_yield:
#                        ^
# SyntaxError: incomplete input

# %%
pesticide=["neem oil","chloropyriphos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
max_effectiveness=max(effectiveness)
print(max_effectiveness)
# Out:
# 90

# %%
min_effectiveness=min(effectiveness)
print(min_effectiveness)
# Out:
# 70

# %%
average_effectiveness=sum(effectiveness)/len(effectiveness)
print(average_effectiveness)
# Out:
# 81.6

# %%
average_effectiveness=sum(effectiveness)/len(effectiveness)
print("most effective pesticide:")
for i in range(len(pesticide)):
  if effectiveness[i]>=average_effectiveness:
               print(pesticide[i])
# Out:
# most effective pesticide:
# chloropyriphos
# imidacloprid
# spinosad

# %%
print("most effective pesticide:")
for i in range(len(pesticide)):
  if effectiveness[i]>80:
               print(pesticide[i])
# Out:
# most effective pesticide:
# chloropyriphos
# imidacloprid
# spinosad

# %%
print("most effective pesticide:")
for i in range(len(pesticide)):
  if effectiveness[i]<80:
               print(pesticide[i])
# Out:
# most effective pesticide:
# neem oil
# malathion

# %%
pesticide=["neem oil","chloropyriphos","malathion","imidacloprid","spinosad"]
--effectiveness=[75,85,70,90,88]  #in %
for p,e in zip(pesticide,effectiveness):
    ne=e+5
    print(ne)
# Out:
# 80
# 90
# 75
# 95
# 93

# %%
pesticide=["neem oil","chloropyriphos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]  #in %
for p,e in zip(pesticide,effectiveness):
  if e>=85:
    print(p,"suitable for organic farming")
# Out:
# chloropyriphos suitable for organic farming
# imidacloprid suitable for organic farming
# spinosad suitable for organic farming

# %%
pesticide=["neem oil","chloropyriphos","malathion","imidacloprid","spinosad"]
effectiveness=[75,85,70,90,88]
for p,e in zip(pesticide,effectiveness):
    if e<=75:
      print(p,'not recommeneded')
# Out:
# neem oil not recommeneded
# malathion not recommeneded

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]
for i in range(len(equipment)):
  max_cost=max(cost)
  index=cost.index(max_cost)
  print("equipment with highest cost:",equipment[index])
# Out:
# equipment with highest cost: harvester
# equipment with highest cost: harvester
# equipment with highest cost: harvester
# equipment with highest cost: harvester
# equipment with highest cost: harvester
# equipment with highest cost: harvester

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]

max_cost = max(cost)
index = cost.index(max_cost)
print("The most expensive farm equipment is:", equipment[index])
# Out:
# The most expensive farm equipment is: harvester

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]

min_cost = min(cost)
index = cost.index(min_cost)
print("The least expensive farm equipment is:", equipment[index])
# Out:
# The least expensive farm equipment is: sprayer

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,60000,18000,95000]

max_cost = max(cost)
min_cost = min(cost)
difference = max_cost - min_cost
print("The most expensive equipment costs:", max_cost)
print("The least expensive equipment costs:", min_cost)
print("The difference in cost is:", difference)
# Out:
# The most expensive equipment costs: 1200000
# The least expensive equipment costs: 18000
# The difference in cost is: 1182000

# %%
list1=[0,20,30,40,50]
list1[0]
# Out:
# 0

# %%
list1=[0,20,30,40,50]
list1[2:4]
# Out:
# [30, 40]

# %%
list1[3:6]
# Out:
# [40, 50]

# %%
list1[2:8]
# Out:
# [30, 40, 50]

# %%
list1[2:5]
# Out:
# [30, 40, 50]

# %%
list1[1:4]
# Out:
# [20, 30, 40]

# %%
list1[-3:-1]
# Out:
# [30, 40]

# %%
list1[-3:-5]
# Out:
# []

# %%
numbers=[10,20,30,40,50,60]
print(numbers[1:6])
print(numbers[1:6:2])
print(numbers[1:6:1])
print(numbers[1:6:])
print(numbers[1:6:3])
# Out:
# [20, 30, 40, 50, 60]
# [20, 40, 60]
# [20, 30, 40, 50, 60]
# [20, 30, 40, 50, 60]
# [20, 50]

# %%
numbers=[10,20,30,40,50,60]
print(numbers[-5:-1])
print(numbers[-5:-1:2])
print(numbers[-5:-1:1])
print(numbers[-5:-1:])
print(numbers[-5:-1:3])
# Out:
# [20, 30, 40, 50]
# [20, 40]
# [20, 30, 40, 50]
# [20, 30, 40, 50]
# [20, 50]

# %%
crops=["rice","wheat","maize","millet","pulses","cotton"]
print(crops[:3])
print(crops[2:5])
print(crops[-5:-1])
print(crops[-2:])
print(crops[: : -1])
print(crops[: : -2])
print(crops[: : 2])
# Out:
# ['rice', 'wheat', 'maize']
# ['maize', 'millet', 'pulses']
# ['wheat', 'maize', 'millet', 'pulses']
# ['pulses', 'cotton']
# ['cotton', 'pulses', 'millet', 'maize', 'wheat', 'rice']
# ['cotton', 'millet', 'wheat']
# ['rice', 'maize', 'pulses']

# %%
numbers=[10,20,30,40,50,60]
for i in numbers:
  print(i+2)
print (numbers)
# Out:
# 12
# 22
# 32
# 42
# 52
# 62
# [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50,60]
n=[]
for i in numbers:
  n.append(i+2)
print(n)
print(numbers)
# Out:
# [12, 22, 32, 42, 52, 62]
# [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50,60]
n=[i+2 for i in numbers]
print("new list",n)
print("original list",numbers)
# Out:
# new list [12, 22, 32, 42, 52, 62]
# original list [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50,60]
n=[]
for i in numbers:
  if i%4==0:
    n.append(i)
print("number divided by 4",n)
print("original list",numbers)
# Out:
# number divided by 4 [20, 40, 60]
# original list [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,20,30,40,50,60]
n=[i for i in numbers if i%4==0]
print("number divided by 4",n)
print("original list",numbers)
# Out:
# number divided by 4 [20, 40, 60]
# original list [10, 20, 30, 40, 50, 60]

# %%
numbers=[10,21,30,41,50,61]
n=["even"if i%2==0 else "odd" for i in numbers]
print(n)
# Out:
# ['even', 'odd', 'even', 'odd', 'even', 'odd']

# %%
#Farm equipments
equipment=['Tractor','Plough','Harvester','Seeder','Sprayer','Thresher']
cost=[850000,25000,1200000,60000,18000,95000]
max_cost=max(cost)
index=cost.index(max_cost)
print('Most epensive equipment is',equipment[index])
# Out:
# Most epensive equipment is Harvester

# %%
min_cost=min(cost)
index=cost.index(min_cost)
print('Least epensive equipment is',equipment[index])
# Out:
# Least epensive equipment is Sprayer

# %%
difference=max(cost)-min(cost)
print('The difference in cost is',difference)
# Out:
# The difference in cost is 1182000

# %%
average_cost=sum(cost)/len(cost)
print('Average cost is',average_cost)
# Out:
# Average cost is 374666.6666666667

# %%
print('equipment with cost above than average cost are')
for i in range(len(equipment)):
  if cost[i]>average_cost:
    print(equipment[i])
# Out:
# equipment with cost above than average cost are
# Tractor
# Harvester

# %%
print('equipment with cost above average cost are')
n=[e for e,c in zip(equipment,cost) if c>average_cost]
print(n)
# Out:
# equipment with cost above average cost are
# ['Tractor', 'Harvester']

# %%
print('equipment with cost equal to average cost is')
n=[e for e,c in zip(equipment,cost) if c==average_cost]
print(n)
# Out:
# equipment with cost equal to average cost is
# []

# %%
print('eqipment with cost less than 50000 are')
n=[e for e,c in zip(equipment,cost) if c<50000]
print(n)
print(len(n))
# Out:
# eqipment with cost less than 50000 are
# ['Plough', 'Sprayer']
# 2

# %%
print('equipment not eligible for government subsidy are')
n=[e for e,c in zip(equipment,cost) if c<=100000]
print(n)
# Out:
# equipment not eligible for government subsidy are
# ['Plough', 'Seeder', 'Sprayer', 'Thresher']

# %%
print('eqipment that require loan support are')
n=[e for e,c in zip (equipment,cost) if c>=500000]
print(n)
# Out:
# eqipment that require loan support are
# ['Tractor', 'Harvester']

# %%
print('equipment suitable for small scale farmers are')
n=[e for e,c in zip(equipment,cost) if c<75000]
print(n)
# Out:
# equipment suitable for small scale farmers are
# ['Plough', 'Seeder', 'Sprayer']

# %%
total=sum(cost)
print('total cost of all eqipment is',total)
# Out:
# total cost of all eqipment is 2248000

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,6000,18000,9500]
updated_cost=[]
for y in cost:
  updated_cost.append(y*1.08)
print("actual cost:",cost)
print("updated cost:",updated_cost)
updated_cost=[int(c*1.08) for c in cost]
print("updated cost after 8% increase:",updated_cost)
# Out:
# actual cost: [850000, 25000, 1200000, 6000, 18000, 9500]
# updated cost: [918000.0000000001, 27000.0, 1296000.0, 6480.0, 19440.0, 10260.0]
# updated cost after 8% increase: [918000, 27000, 1296000, 6480, 19440, 10260]

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000.123,25000.133,1200000.143,6000.153,18000.163,9500.173]
updated_cost=[]
for y in cost:
  updated_cost.append(round((y*1.08),2))
print("actual cost:",cost)
print("updated cost:",updated_cost)
# Out:
# actual cost: [850000.123, 25000.133, 1200000.143, 6000.153, 18000.163, 9500.173]
# updated cost: [918000.13, 27000.14, 1296000.15, 6480.17, 19440.18, 10260.19]

# %%
equipment=["tractor","plough","harvester","seeder","sprayer","thresher"]
cost=[850000,25000,1200000,6000,18000,9500]
equipment_updated=[]
for i in range(len(equipment)):
    if updated_cost[i]>1000000:
      equipment_updated.append("high investment")
    else:
      equipment_updated.append(equipment[i])
print("equipment list after replacement:\n",equipment_updated)
# Out:
# equipment list after replacement:
#  ['tractor', 'plough', 'high investment', 'seeder', 'sprayer', 'thresher']

# %%
equiment_updated=[
    "high investment" if c>1000000 else e
    for e,c in zip(equipment,updated_cost)
]
print(equiment_updated)
# Out:
# ['tractor', 'plough', 'high investment', 'seeder', 'sprayer', 'thresher']

# %%
categories=[]
for c in updated_cost:
  if c<1000000:
    categories.append("low")
  elif c<=500000:
    categories.append("medium")
  else:
    categories.append("high")
print("cost categories:",categories)
# Out:
# cost categories: ['low', 'low', 'high', 'low', 'low', 'low']

# %%
subsidy_cost=[]
for c in cost:
  if c<100000:
    subsidy_cost.append(int(c*0.85))
  else:
    subsidy_cost.append(c)
print("cost after subsidy:",subsidy_cost)
# Out:
# cost after subsidy: [850000, 21250, 1200000, 5100, 15300, 8075]

# %%
equipment=['Tractor','Plough','Harvester','Seeder','Sprayer','Thresher']
cost=[850000,25000,1200000,60000,18000,95000]
new=[c*.85 if c>=100000 else c for c in cost]
print('After reducing cost by 15%\n',new)
print('Original cost\n',cost)
subsidy_cost=[]
for y in cost:
  if y>=100000:
    subsidy_cost.append(y*0.85)
  else:
    subsidy_cost.append(y)
print('After reducing\n',subsidy_cost)
# Out:
# After reducing cost by 15%
#  [722500.0, 25000, 1020000.0, 60000, 18000, 95000]
# Original cost
#  [850000, 25000, 1200000, 60000, 18000, 95000]
# After reducing
#  [722500.0, 25000, 1020000.0, 60000, 18000, 95000]

# %%
print(bool(1))
print(bool(0))
print(False)
# Out:
# True
# False
# False

# %%
for i in range(1,21):
  if i%2==0:
    print(i,"is even")
  else:
    print(i,"is odd")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
# 11 is odd
# 12 is even
# 13 is odd
# 14 is even
# 15 is odd
# 16 is even
# 17 is odd
# 18 is even
# 19 is odd
# 20 is even

# %%
i=1
while(i<=20):
  if i%2==0:
    print(i)
  i+=2

# %%
i=1
while(i<20):
  if i%3==0 or i%5==0:
    print(i)
    i+=1

# %%
i=1
while(i<=10)
if 1==6:
  break
print(i)
i+=1
